# %%
import pandas as pd
import ast

# %%
df1=pd.read_excel("data2.xlsx")

# %%
df1
# Out:
#    id   name  friends liked_pages
# 0   1   Amit    [2,3]       [101]
# 1   2  Priya    [1,4]       [102]
# 2   3    NaN      [1]   [101,103]
# 3   4   Sara    [2,2]       [104]
# 4   5   Amit       []          []
# 5   6  Rahul  [1,3,3]   [101,105]
# 6   7   Neha       []          []
# 7   8    NaN    [2,3]          []
# 8   9  Pooja  [4,4,4]       [106]
# 9   4   Sara  [2,2,3]       [104]

# %%
df2=df1.dropna()

# %%
df2
# Out:
#    id   name  friends liked_pages
# 0   1   Amit    [2,3]       [101]
# 1   2  Priya    [1,4]       [102]
# 3   4   Sara    [2,2]       [104]
# 4   5   Amit       []          []
# 5   6  Rahul  [1,3,3]   [101,105]
# 6   7   Neha       []          []
# 8   9  Pooja  [4,4,4]       [106]
# 9   4   Sara  [2,2,3]       [104]

# %%
df2["friends"] = df2["friends"].apply(lambda x: list(dict.fromkeys(x)) if isinstance(x, list) else x)
# Out:
# C:\Users\phuta\AppData\Local\Temp\ipykernel_19548\632861697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["friends"] = df2["friends"].apply(lambda x: list(dict.fromkeys(x)) if isinstance(x, list) else x)

# %%
df2
# Out:
#    id   name  friends liked_pages
# 0   1   Amit    [2,3]       [101]
# 1   2  Priya    [1,4]       [102]
# 3   4   Sara    [2,2]       [104]
# 4   5   Amit       []          []
# 5   6  Rahul  [1,3,3]   [101,105]
# 6   7   Neha       []          []
# 8   9  Pooja  [4,4,4]       [106]
# 9   4   Sara  [2,2,3]       [104]

# %%
df2["friends"] = df2["friends"].apply(ast.literal_eval)
df2 = df2[df2["friends"].apply(lambda x: len(x) > 0)]
# Out:
# C:\Users\phuta\AppData\Local\Temp\ipykernel_19548\864970786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["friends"] = df2["friends"].apply(ast.literal_eval)

# %%
df2
# Out:
#    id   name    friends liked_pages
# 0   1   Amit     [2, 3]       [101]
# 1   2  Priya     [1, 4]       [102]
# 3   4   Sara     [2, 2]       [104]
# 5   6  Rahul  [1, 3, 3]   [101,105]
# 8   9  Pooja  [4, 4, 4]       [106]
# 9   4   Sara  [2, 2, 3]       [104]

# %%
df4=pd.read_excel("data4.xlsx")

# %%
df4
# Out:
#    page_id       page_name     category  likes
# 0      101      Tech World   Technology   1200
# 1      102    Travel Buddy       Travel    800
# 2      103     Food Lovers         Food   1500
# 3      104     Music Vibes        Music    950
# 4      105  Fitness Freaks       Health   1100
# 5      102    Travel Buddy       Travel    800
# 6      106  Bookworms Club    Education    650
# 7      101      Tech World   Technology   1200
# 8      107    Nature Bliss  Photography    700
# 9      108      Tech World   Technology    300

# %%
df4=df4.drop_duplicates()

# %%
df4
# Out:
#    page_id       page_name     category  likes
# 0      101      Tech World   Technology   1200
# 1      102    Travel Buddy       Travel    800
# 2      103     Food Lovers         Food   1500
# 3      104     Music Vibes        Music    950
# 4      105  Fitness Freaks       Health   1100
# 6      106  Bookworms Club    Education    650
# 8      107    Nature Bliss  Photography    700
# 9      108      Tech World   Technology    300

# %%
df2.to_excel("Cleaned_data_for_users.xlsx",index=False)

# %%
df4.to_excel("Cleaned_data_for_pages.xlsx",index=False)
